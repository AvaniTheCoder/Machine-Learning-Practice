# %% [markdown]
# <a href="https://colab.research.google.com/github/AvaniTheCoder/Machine-Learning-Practice/blob/main/Day1ML_10_8_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

#Generate some sample data
X=np.array([1,2,3,4,5]).reshape(-1,1)  #Features(input)
y=np.array([2,3.9,5.8,8.1,9.7])  #Labels

#Create a linear regression
model = LinearRegression()

#Train the model on the data
model.fit(X,y)

#Make predictions for new data points
new_X = np.array([6,7,8]).reshape(-1,1)
predictions = model.predict(new_X)

#Plot the original data points and linear regression line
plt.scatter(X,y, label='Original data')
plt.plot(new_X, predictions, color="red", label="Linear regression line")
plt.xlabel('X (Feature)')
plt.ylabel('y (Label)')
plt.title('Linear regression example')
plt.legend()
plt.show()

# %%
#Blood pressure and age
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

#Generate some sample data
X=np.array([20,30,40,50,60]).reshape(-1,1)  #Features(input)
y=np.array([110,122,139,150,163])  #Labels

#Create a linear regression
model = LinearRegression()

#Train the model on the data
model.fit(X,y)

#Make predictions for new data points
new_X = np.array([35,47,70]).reshape(-1,1)
predictions = model.predict(new_X)

#Plot the original data points and linear regression line
plt.scatter(X,y, label='Original data')
plt.plot(new_X, predictions, color="red", label="Linear regression line")
plt.xlabel('X (Age)')
plt.ylabel('y (Blood pressure)')
plt.title('Linear regression example')
plt.legend()
plt.show()

# %%
#Blood pressure and age
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


#Generate some sample data
X=np.random.randint(20,80,300).reshape(-1,1)  #Features(input)
y=np.random.randint(110,190,300)  #Labels

#Create a linear regression
model = LinearRegression()

#Train the model on the data
model.fit(X,y)

#Make predictions for new data points
new_X = np.array([35,47,70]).reshape(-1,1)
predictions = model.predict(new_X)

#Plot the original data points and linear regression line
plt.scatter(X,y, label='Original data')
plt.plot(new_X, predictions, color="red", label="Linear regression line")
plt.xlabel('X (Age)')
plt.ylabel('y (Blood pressure)')
plt.title('Linear regression example')
plt.legend()
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

#Load the iris data
iris = load_iris()
X,y = iris.data, iris.target

#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

#Create the KNeighborClassifier model
model = KNeighborsClassifier(n_neighbors=3)

#Train the model on the training data
model.fit(X_train,y_train)

#Make prediction on the testing data
predictions=model.predict(X_test)

#Calculate the accracy of the model
accuracy=accuracy_score(y_test,predictions)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 1.0
